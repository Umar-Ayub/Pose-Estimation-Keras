# %%
import tensorflow as tf
# import tensorflow.contrib.eager as tfe
# tfe.enable_eager_execution()
import sys
sys.path.append(r'~/Pose-Estimation-Keras')
import cnn
from cnn import conv_base
from build_dataset import Dataset
import numpy as np
from sklearn.preprocessing import normalize
from scipy import stats

from keras import layers
from keras import models
from keras import optimizers
import keras.backend as K
from keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler

from time import time
import cv2
import os
# Out:
# Using TensorFlow backend.
# /home/bhandawatlab_duke/.local/lib/python3.5/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
# Some Hyperparameters
total_frames = 5
frame_height = 224
frame_width = 224
frame_channels = 3
num_bodyparts = 6

# %%
def build_deconv_model():
    frame_tensor = conv_base.layers[0].get_input_at(0)
    resnet_output = cnn.convolution_network(frame_tensor)
    model_resnet = models.Model(inputs=[frame_tensor], outputs=[resnet_output])
    
    deconv_output = cnn.deconvolution_network(model_resnet.output)
#     model_deconv = models.Model(inputs=[frame_tensor], outputs=[deconv_output])
    
    
    deconv_fusion_output = cnn.deconvolution_fusion_network(model_resnet.output)
#     model_deconv_fusion = models.Model(inputs=[frame_tensor], outputs=[deconv_fusion_output])
    model = models.Model(inputs=[frame_tensor], outputs=[deconv_output, deconv_fusion_output])
    
    
    losses = {
        "deconvolution_network_output": "binary_crossentropy",
        "deconvolution_fusion_network_output": "binary_crossentropy"
#         "spatial_fusion_output": "binary_crossentropy",
#         "optical_flow_output": "binary_crossentropy"
    }
    lossWeights = {"deconvolution_network_output": 1.0,
                   "deconvolution_fusion_network_output": 1.0}
#                    "spatial_fusion_output": 1.0,
#                    "optical_flow_output": 1.0}

    opt = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)
    model.compile( optimizer=opt, loss=losses, loss_weights=lossWeights, metrics = ["accuracy"])
    
    return model

model = build_deconv_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# resnet50 (Model)                (None, 7, 7, 2048)   23587712    input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 14, 14, 30)   552990      resnet50[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 14, 14, 30)   552990      resnet50[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 28, 28, 24)   6504        conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 28, 28, 24)   6504        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 56, 56, 18)   3906        conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 56, 56, 18)   3906        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 112, 112, 12) 1956        conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 112, 112, 12) 1956        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# same (Conv2DTranspose)          (None, 224, 224, 6)  654         conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# deconvolution_network_output (C (None, 224, 224, 6)  654         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# deconvolution_fusion_network_ou (None, 224, 224, 1)  55          same[0][0]
# ==================================================================================================
# Total params: 24,719,787
# Trainable params: 24,666,667
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import csv
def parse_csv(file):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        indices = []
        for line in csv_reader:
            indices.extend([int(f) for f in line if f!=''])
    return indices

indices = parse_csv('dataset_indices.csv')
print(indices)
# Out:
# [0, 2, 3, 4, 6, 7, 8, 11, 15, 16, 17, 18, 19, 20, 23, 120, 126, 127, 178, 185, 199, 228, 244, 261, 267, 285, 306, 335, 367, 375, 389, 405, 410, 415, 420, 426, 430, 436, 440, 445, 452, 455, 460, 465, 470, 476, 480, 485, 490, 496, 500, 511, 520, 525, 530, 535, 542, 552, 555, 568, 570, 575, 581, 588, 595, 600, 605, 610, 615, 621, 625, 633, 636, 640, 645, 650, 655, 665, 670, 675, 680, 685, 690, 695, 700, 705, 710, 715, 718, 723, 725, 751, 755, 770, 783, 784, 804, 812, 816, 823, 829, 838, 841, 845, 850, 855, 863, 865, 891, 894, 904, 908, 915, 920, 929, 946, 953, 955, 959, 965, 970, 980, 987, 990, 995, 1030, 1035, 1041, 1045, 1160, 1164, 1170, 1174, 1220, 1225, 1230, 1235, 1240, 1245, 1250, 1255, 1267, 1275, 1280, 1285, 1290]

# %%
import h5py
with h5py.File('../dataset.h5', 'r') as hf:
#     central_heatmap = hf['central_heatmap'][indices]
    frames = hf['frames'][indices]
    heatmaps_individual = hf['heatmaps_individual'][indices]
    heatmaps_combined = hf['heatmaps_combined'][indices]

# %%
home_dir = os.getcwd()
# central_heatmap = np.expand_dims(central_heatmap, axis=-1)
heatmaps_combined = np.expand_dims(heatmaps_combined, axis=-1)
heatmaps_individual = np.swapaxes(heatmaps_individual, 2, 4)
# print(central_heatmap.shape)
print(heatmaps_individual.shape)
print(heatmaps_combined.shape)
# Out:
# (146, 5, 224, 224, 6)
# (146, 5, 224, 224, 1)

# %%
def step_decay(epoch):
    try:
        if epoch < 30:
            lrate = 0.0001
        elif epoch < 70:
            lrate = 0.00005
        elif epoch < 200:
            lrate = 0.00001
        return lrate
    except:
        print('Error in setting learning rate')
lrate = LearningRateScheduler(step_decay, verbose=1)

checkpointer = ModelCheckpoint(filepath= os.path.join(home_dir, "pretrained_models/model_sep_fusion_11119.h5"),
                               verbose=1,
                               monitor='loss')

tensorboard = TensorBoard(log_dir=os.path.join(home_dir, "logs/{}".format(time())))

# %%
def normalize(x):
    x = np.array(x, dtype = np.float64)
    x -= np.mean(x, dtype = np.float64)
    x /= np.std(x, dtype = np.float64)
    return x


def generator(frames, heatmaps_individual, heatmaps_combined):
    while(1):
        for j,l,m in zip(frames, heatmaps_individual, heatmaps_combined):
#             print(l.shape[0])
            for channel in range(l.shape[0]):
                l[channel, :, :, :] = normalize(l[channel, :, :, :]) 
                m[channel, :, :, :] = normalize(m[channel, :, :, :])
            # include batch dimension and repeat the matrix at axis 0 num_frames times to match the target dimensionality
            yield (j, {
#                 "optical_flow_output" : np.repeat(np.expand_dims(k, axis=0), 5, 0), 
                "deconvolution_network_output": l,
                "deconvolution_fusion_network_output": m}) 
            
model.fit_generator(generator(frames,heatmaps_individual, heatmaps_combined),
                           steps_per_epoch=100, 
                           verbose = 1,
                           epochs = 150,
                           callbacks=[lrate, checkpointer, tensorboard])
# Out:
# Epoch 1/150
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 38s 375ms/step - loss: -0.0820 - deconvolution_network_output_loss: -0.0692 - deconvolution_fusion_network_output_loss: -0.0383 - deconvolution_network_output_acc: 0.9903 - deconvolution_fusion_network_output_acc: 0.9876
#
# Epoch 00001: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 2/150
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 365ms/step - loss: -0.1012 - deconvolution_network_output_loss: -0.0829 - deconvolution_fusion_network_output_loss: -0.0441 - deconvolution_network_output_acc: 0.9908 - deconvolution_fusion_network_output_acc: 0.9886
#
# Epoch 00002: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 3/150
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.1090 - deconvolution_network_output_loss: -0.0888 - deconvolution_fusion_network_output_loss: -0.0461 - deconvolution_network_output_acc: 0.9903 - deconvolution_fusion_network_output_acc: 0.9882
#
# Epoch 00003: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 4/150
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.1160 - deconvolution_network_output_loss: -0.0910 - deconvolution_fusion_network_output_loss: -0.0510 - deconvolution_network_output_acc: 0.9908 - deconvolution_fusion_network_output_acc: 0.9884
#
# Epoch 00004: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 5/150
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 365ms/step - loss: -0.1321 - deconvolution_network_output_loss: -0.1027 - deconvolution_fusion_network_output_loss: -0.0556 - deconvolution_network_output_acc: 0.9906 - deconvolution_fusion_network_output_acc: 0.9890
#
# Epoch 00005: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 6/150
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.1439 - deconvolution_network_output_loss: -0.1121 - deconvolution_fusion_network_output_loss: -0.0583 - deconvolution_network_output_acc: 0.9912 - deconvolution_fusion_network_output_acc: 0.9888
#
# Epoch 00006: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 7/150
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.1492 - deconvolution_network_output_loss: -0.1150 - deconvolution_fusion_network_output_loss: -0.0609 - deconvolution_network_output_acc: 0.9907 - deconvolution_fusion_network_output_acc: 0.9883
#
# Epoch 00007: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 8/150
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.1626 - deconvolution_network_output_loss: -0.1236 - deconvolution_fusion_network_output_loss: -0.0660 - deconvolution_network_output_acc: 0.9908 - deconvolution_fusion_network_output_acc: 0.9893
#
# Epoch 00008: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 9/150
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.1790 - deconvolution_network_output_loss: -0.1358 - deconvolution_fusion_network_output_loss: -0.0704 - deconvolution_network_output_acc: 0.9913 - deconvolution_fusion_network_output_acc: 0.9897
#
# Epoch 00009: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 10/150
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 365ms/step - loss: -0.1840 - deconvolution_network_output_loss: -0.1365 - deconvolution_fusion_network_output_loss: -0.0749 - deconvolution_network_output_acc: 0.9912 - deconvolution_fusion_network_output_acc: 0.9896
#
# Epoch 00010: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 11/150
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.1961 - deconvolution_network_output_loss: -0.1437 - deconvolution_fusion_network_output_loss: -0.0799 - deconvolution_network_output_acc: 0.9913 - deconvolution_fusion_network_output_acc: 0.9901
#
# Epoch 00011: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 12/150
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.2108 - deconvolution_network_output_loss: -0.1558 - deconvolution_fusion_network_output_loss: -0.0828 - deconvolution_network_output_acc: 0.9920 - deconvolution_fusion_network_output_acc: 0.9903
#
# Epoch 00012: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 13/150
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.2218 - deconvolution_network_output_loss: -0.1605 - deconvolution_fusion_network_output_loss: -0.0893 - deconvolution_network_output_acc: 0.9920 - deconvolution_fusion_network_output_acc: 0.9906
#
# Epoch 00013: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 14/150
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.2292 - deconvolution_network_output_loss: -0.1653 - deconvolution_fusion_network_output_loss: -0.0921 - deconvolution_network_output_acc: 0.9920 - deconvolution_fusion_network_output_acc: 0.9907
#
# Epoch 00014: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 15/150
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.2457 - deconvolution_network_output_loss: -0.1773 - deconvolution_fusion_network_output_loss: -0.0967 - deconvolution_network_output_acc: 0.9931 - deconvolution_fusion_network_output_acc: 0.9913
#
# Epoch 00015: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 16/150
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.2547 - deconvolution_network_output_loss: -0.1831 - deconvolution_fusion_network_output_loss: -0.1000 - deconvolution_network_output_acc: 0.9931 - deconvolution_fusion_network_output_acc: 0.9908
#
# Epoch 00016: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 17/150
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.2573 - deconvolution_network_output_loss: -0.1815 - deconvolution_fusion_network_output_loss: -0.1044 - deconvolution_network_output_acc: 0.9932 - deconvolution_fusion_network_output_acc: 0.9911
#
# Epoch 00017: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 18/150
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.2655 - deconvolution_network_output_loss: -0.1874 - deconvolution_fusion_network_output_loss: -0.1068 - deconvolution_network_output_acc: 0.9935 - deconvolution_fusion_network_output_acc: 0.9913
#
# Epoch 00018: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 19/150
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.2756 - deconvolution_network_output_loss: -0.1916 - deconvolution_fusion_network_output_loss: -0.1128 - deconvolution_network_output_acc: 0.9937 - deconvolution_fusion_network_output_acc: 0.9915
#
# Epoch 00019: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 20/150
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 365ms/step - loss: -0.2848 - deconvolution_network_output_loss: -0.1960 - deconvolution_fusion_network_output_loss: -0.1176 - deconvolution_network_output_acc: 0.9940 - deconvolution_fusion_network_output_acc: 0.9920
#
# Epoch 00020: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 21/150
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.2948 - deconvolution_network_output_loss: -0.2023 - deconvolution_fusion_network_output_loss: -0.1213 - deconvolution_network_output_acc: 0.9942 - deconvolution_fusion_network_output_acc: 0.9920
#
# Epoch 00021: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 22/150
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.3007 - deconvolution_network_output_loss: -0.2051 - deconvolution_fusion_network_output_loss: -0.1245 - deconvolution_network_output_acc: 0.9947 - deconvolution_fusion_network_output_acc: 0.9920
#
# Epoch 00022: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 23/150
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.3042 - deconvolution_network_output_loss: -0.2039 - deconvolution_fusion_network_output_loss: -0.1293 - deconvolution_network_output_acc: 0.9944 - deconvolution_fusion_network_output_acc: 0.9921
#
# Epoch 00023: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 24/150
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 358ms/step - loss: -0.3137 - deconvolution_network_output_loss: -0.2094 - deconvolution_fusion_network_output_loss: -0.1333 - deconvolution_network_output_acc: 0.9949 - deconvolution_fusion_network_output_acc: 0.9923
#
# Epoch 00024: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 25/150
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.3201 - deconvolution_network_output_loss: -0.2125 - deconvolution_fusion_network_output_loss: -0.1366 - deconvolution_network_output_acc: 0.9951 - deconvolution_fusion_network_output_acc: 0.9923
#
# Epoch 00025: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 26/150
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.3230 - deconvolution_network_output_loss: -0.2121 - deconvolution_fusion_network_output_loss: -0.1400 - deconvolution_network_output_acc: 0.9950 - deconvolution_fusion_network_output_acc: 0.9923
#
# Epoch 00026: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 27/150
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.3299 - deconvolution_network_output_loss: -0.2138 - deconvolution_fusion_network_output_loss: -0.1452 - deconvolution_network_output_acc: 0.9953 - deconvolution_fusion_network_output_acc: 0.9924
#
# Epoch 00027: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 28/150
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.3309 - deconvolution_network_output_loss: -0.2136 - deconvolution_fusion_network_output_loss: -0.1466 - deconvolution_network_output_acc: 0.9951 - deconvolution_fusion_network_output_acc: 0.9924
#
# Epoch 00028: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 29/150
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.3307 - deconvolution_network_output_loss: -0.2102 - deconvolution_fusion_network_output_loss: -0.1497 - deconvolution_network_output_acc: 0.9951 - deconvolution_fusion_network_output_acc: 0.9922
#
# Epoch 00029: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 30/150
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.3381 - deconvolution_network_output_loss: -0.2138 - deconvolution_fusion_network_output_loss: -0.1536 - deconvolution_network_output_acc: 0.9953 - deconvolution_fusion_network_output_acc: 0.9920
#
# Epoch 00030: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 31/150
#
# Epoch 00031: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.3429 - deconvolution_network_output_loss: -0.2164 - deconvolution_fusion_network_output_loss: -0.1558 - deconvolution_network_output_acc: 0.9953 - deconvolution_fusion_network_output_acc: 0.9921
#
# Epoch 00031: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 32/150
#
# Epoch 00032: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.3538 - deconvolution_network_output_loss: -0.2234 - deconvolution_fusion_network_output_loss: -0.1598 - deconvolution_network_output_acc: 0.9958 - deconvolution_fusion_network_output_acc: 0.9926
#
# Epoch 00032: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 33/150
#
# Epoch 00033: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.3659 - deconvolution_network_output_loss: -0.2304 - deconvolution_fusion_network_output_loss: -0.1648 - deconvolution_network_output_acc: 0.9962 - deconvolution_fusion_network_output_acc: 0.9930
#
# Epoch 00033: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 34/150
#
# Epoch 00034: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.3713 - deconvolution_network_output_loss: -0.2337 - deconvolution_fusion_network_output_loss: -0.1669 - deconvolution_network_output_acc: 0.9965 - deconvolution_fusion_network_output_acc: 0.9934
#
# Epoch 00034: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 35/150
#
# Epoch 00035: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.3797 - deconvolution_network_output_loss: -0.2375 - deconvolution_fusion_network_output_loss: -0.1714 - deconvolution_network_output_acc: 0.9968 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00035: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 36/150
#
# Epoch 00036: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.3839 - deconvolution_network_output_loss: -0.2382 - deconvolution_fusion_network_output_loss: -0.1748 - deconvolution_network_output_acc: 0.9967 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00036: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 37/150
#
# Epoch 00037: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.3864 - deconvolution_network_output_loss: -0.2400 - deconvolution_fusion_network_output_loss: -0.1756 - deconvolution_network_output_acc: 0.9969 - deconvolution_fusion_network_output_acc: 0.9939
#
# Epoch 00037: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 38/150
#
# Epoch 00038: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.3911 - deconvolution_network_output_loss: -0.2414 - deconvolution_fusion_network_output_loss: -0.1787 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9941
#
# Epoch 00038: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 39/150
#
# Epoch 00039: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.3945 - deconvolution_network_output_loss: -0.2420 - deconvolution_fusion_network_output_loss: -0.1816 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9941
#
# Epoch 00039: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 40/150
#
# Epoch 00040: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 365ms/step - loss: -0.3971 - deconvolution_network_output_loss: -0.2433 - deconvolution_fusion_network_output_loss: -0.1827 - deconvolution_network_output_acc: 0.9972 - deconvolution_fusion_network_output_acc: 0.9940
#
# Epoch 00040: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 41/150
#
# Epoch 00041: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.3993 - deconvolution_network_output_loss: -0.2441 - deconvolution_fusion_network_output_loss: -0.1841 - deconvolution_network_output_acc: 0.9972 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00041: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 42/150
#
# Epoch 00042: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4021 - deconvolution_network_output_loss: -0.2436 - deconvolution_fusion_network_output_loss: -0.1873 - deconvolution_network_output_acc: 0.9972 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00042: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 43/150
#
# Epoch 00043: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4053 - deconvolution_network_output_loss: -0.2445 - deconvolution_fusion_network_output_loss: -0.1896 - deconvolution_network_output_acc: 0.9973 - deconvolution_fusion_network_output_acc: 0.9941
#
# Epoch 00043: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 44/150
#
# Epoch 00044: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4069 - deconvolution_network_output_loss: -0.2455 - deconvolution_fusion_network_output_loss: -0.1901 - deconvolution_network_output_acc: 0.9973 - deconvolution_fusion_network_output_acc: 0.9942
#
# Epoch 00044: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 45/150
#
# Epoch 00045: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4083 - deconvolution_network_output_loss: -0.2440 - deconvolution_fusion_network_output_loss: -0.1930 - deconvolution_network_output_acc: 0.9972 - deconvolution_fusion_network_output_acc: 0.9944
#
# Epoch 00045: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 46/150
#
# Epoch 00046: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4110 - deconvolution_network_output_loss: -0.2451 - deconvolution_fusion_network_output_loss: -0.1946 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9941
#
# Epoch 00046: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 47/150
#
# Epoch 00047: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.4135 - deconvolution_network_output_loss: -0.2459 - deconvolution_fusion_network_output_loss: -0.1961 - deconvolution_network_output_acc: 0.9973 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00047: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 48/150
#
# Epoch 00048: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4142 - deconvolution_network_output_loss: -0.2450 - deconvolution_fusion_network_output_loss: -0.1977 - deconvolution_network_output_acc: 0.9973 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00048: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 49/150
#
# Epoch 00049: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4173 - deconvolution_network_output_loss: -0.2455 - deconvolution_fusion_network_output_loss: -0.2003 - deconvolution_network_output_acc: 0.9973 - deconvolution_fusion_network_output_acc: 0.9941
#
# Epoch 00049: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 50/150
#
# Epoch 00050: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4167 - deconvolution_network_output_loss: -0.2447 - deconvolution_fusion_network_output_loss: -0.2004 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00050: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 51/150
#
# Epoch 00051: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4196 - deconvolution_network_output_loss: -0.2453 - deconvolution_fusion_network_output_loss: -0.2027 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9942
#
# Epoch 00051: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 52/150
#
# Epoch 00052: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4209 - deconvolution_network_output_loss: -0.2448 - deconvolution_fusion_network_output_loss: -0.2045 - deconvolution_network_output_acc: 0.9973 - deconvolution_fusion_network_output_acc: 0.9939
#
# Epoch 00052: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 53/150
#
# Epoch 00053: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4180 - deconvolution_network_output_loss: -0.2431 - deconvolution_fusion_network_output_loss: -0.2032 - deconvolution_network_output_acc: 0.9972 - deconvolution_fusion_network_output_acc: 0.9939
#
# Epoch 00053: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 54/150
#
# Epoch 00054: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4222 - deconvolution_network_output_loss: -0.2450 - deconvolution_fusion_network_output_loss: -0.2055 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00054: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 55/150
#
# Epoch 00055: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4216 - deconvolution_network_output_loss: -0.2413 - deconvolution_fusion_network_output_loss: -0.2086 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00055: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 56/150
#
# Epoch 00056: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4209 - deconvolution_network_output_loss: -0.2405 - deconvolution_fusion_network_output_loss: -0.2086 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9936
#
# Epoch 00056: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 57/150
#
# Epoch 00057: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4210 - deconvolution_network_output_loss: -0.2389 - deconvolution_fusion_network_output_loss: -0.2103 - deconvolution_network_output_acc: 0.9973 - deconvolution_fusion_network_output_acc: 0.9939
#
# Epoch 00057: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 58/150
#
# Epoch 00058: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4232 - deconvolution_network_output_loss: -0.2376 - deconvolution_fusion_network_output_loss: -0.2138 - deconvolution_network_output_acc: 0.9969 - deconvolution_fusion_network_output_acc: 0.9939
#
# Epoch 00058: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 59/150
#
# Epoch 00059: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4220 - deconvolution_network_output_loss: -0.2375 - deconvolution_fusion_network_output_loss: -0.2128 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9934
#
# Epoch 00059: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 60/150
#
# Epoch 00060: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4276 - deconvolution_network_output_loss: -0.2405 - deconvolution_fusion_network_output_loss: -0.2153 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00060: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 61/150
#
# Epoch 00061: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4242 - deconvolution_network_output_loss: -0.2342 - deconvolution_fusion_network_output_loss: -0.2182 - deconvolution_network_output_acc: 0.9969 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00061: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 62/150
#
# Epoch 00062: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4274 - deconvolution_network_output_loss: -0.2348 - deconvolution_fusion_network_output_loss: -0.2208 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9937
#
# Epoch 00062: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 63/150
#
# Epoch 00063: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4330 - deconvolution_network_output_loss: -0.2391 - deconvolution_fusion_network_output_loss: -0.2221 - deconvolution_network_output_acc: 0.9968 - deconvolution_fusion_network_output_acc: 0.9940
#
# Epoch 00063: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 64/150
#
# Epoch 00064: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4298 - deconvolution_network_output_loss: -0.2345 - deconvolution_fusion_network_output_loss: -0.2235 - deconvolution_network_output_acc: 0.9968 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00064: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 65/150
#
# Epoch 00065: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4350 - deconvolution_network_output_loss: -0.2376 - deconvolution_fusion_network_output_loss: -0.2256 - deconvolution_network_output_acc: 0.9972 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00065: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 66/150
#
# Epoch 00066: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4421 - deconvolution_network_output_loss: -0.2419 - deconvolution_fusion_network_output_loss: -0.2283 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9941
#
# Epoch 00066: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 67/150
#
# Epoch 00067: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4377 - deconvolution_network_output_loss: -0.2377 - deconvolution_fusion_network_output_loss: -0.2281 - deconvolution_network_output_acc: 0.9970 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00067: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 68/150
#
# Epoch 00068: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4463 - deconvolution_network_output_loss: -0.2421 - deconvolution_fusion_network_output_loss: -0.2323 - deconvolution_network_output_acc: 0.9972 - deconvolution_fusion_network_output_acc: 0.9940
#
# Epoch 00068: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 69/150
#
# Epoch 00069: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4510 - deconvolution_network_output_loss: -0.2456 - deconvolution_fusion_network_output_loss: -0.2334 - deconvolution_network_output_acc: 0.9975 - deconvolution_fusion_network_output_acc: 0.9942
#
# Epoch 00069: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 70/150
#
# Epoch 00070: LearningRateScheduler setting learning rate to 5e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4500 - deconvolution_network_output_loss: -0.2439 - deconvolution_fusion_network_output_loss: -0.2341 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9938
#
# Epoch 00070: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 71/150
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4482 - deconvolution_network_output_loss: -0.2404 - deconvolution_fusion_network_output_loss: -0.2359 - deconvolution_network_output_acc: 0.9967 - deconvolution_fusion_network_output_acc: 0.9940
#
# Epoch 00071: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 72/150
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 365ms/step - loss: -0.4524 - deconvolution_network_output_loss: -0.2440 - deconvolution_fusion_network_output_loss: -0.2363 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9939
#
# Epoch 00072: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 73/150
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4551 - deconvolution_network_output_loss: -0.2456 - deconvolution_fusion_network_output_loss: -0.2375 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9941
#
# Epoch 00073: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 74/150
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4588 - deconvolution_network_output_loss: -0.2466 - deconvolution_fusion_network_output_loss: -0.2402 - deconvolution_network_output_acc: 0.9974 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00074: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 75/150
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4626 - deconvolution_network_output_loss: -0.2504 - deconvolution_fusion_network_output_loss: -0.2403 - deconvolution_network_output_acc: 0.9978 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00075: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 76/150
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4607 - deconvolution_network_output_loss: -0.2490 - deconvolution_fusion_network_output_loss: -0.2396 - deconvolution_network_output_acc: 0.9977 - deconvolution_fusion_network_output_acc: 0.9944
#
# Epoch 00076: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 77/150
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 356ms/step - loss: -0.4629 - deconvolution_network_output_loss: -0.2486 - deconvolution_fusion_network_output_loss: -0.2423 - deconvolution_network_output_acc: 0.9976 - deconvolution_fusion_network_output_acc: 0.9944
#
# Epoch 00077: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 78/150
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4652 - deconvolution_network_output_loss: -0.2511 - deconvolution_fusion_network_output_loss: -0.2420 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9943
#
# Epoch 00078: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 79/150
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.4643 - deconvolution_network_output_loss: -0.2505 - deconvolution_fusion_network_output_loss: -0.2418 - deconvolution_network_output_acc: 0.9978 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00079: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 80/150
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4648 - deconvolution_network_output_loss: -0.2498 - deconvolution_fusion_network_output_loss: -0.2429 - deconvolution_network_output_acc: 0.9977 - deconvolution_fusion_network_output_acc: 0.9944
#
# Epoch 00080: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 81/150
#
# Epoch 00081: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4677 - deconvolution_network_output_loss: -0.2514 - deconvolution_fusion_network_output_loss: -0.2442 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9944
#
# Epoch 00081: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 82/150
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4666 - deconvolution_network_output_loss: -0.2516 - deconvolution_fusion_network_output_loss: -0.2430 - deconvolution_network_output_acc: 0.9978 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00082: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 83/150
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4662 - deconvolution_network_output_loss: -0.2506 - deconvolution_fusion_network_output_loss: -0.2435 - deconvolution_network_output_acc: 0.9978 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00083: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 84/150
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4693 - deconvolution_network_output_loss: -0.2514 - deconvolution_fusion_network_output_loss: -0.2458 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00084: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 85/150
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4682 - deconvolution_network_output_loss: -0.2522 - deconvolution_fusion_network_output_loss: -0.2439 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00085: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 86/150
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4692 - deconvolution_network_output_loss: -0.2515 - deconvolution_fusion_network_output_loss: -0.2455 - deconvolution_network_output_acc: 0.9978 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00086: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 87/150
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4706 - deconvolution_network_output_loss: -0.2517 - deconvolution_fusion_network_output_loss: -0.2467 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00087: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 88/150
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4698 - deconvolution_network_output_loss: -0.2525 - deconvolution_fusion_network_output_loss: -0.2452 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00088: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 89/150
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4711 - deconvolution_network_output_loss: -0.2524 - deconvolution_fusion_network_output_loss: -0.2464 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00089: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 90/150
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4724 - deconvolution_network_output_loss: -0.2517 - deconvolution_fusion_network_output_loss: -0.2485 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00090: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 91/150
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4714 - deconvolution_network_output_loss: -0.2529 - deconvolution_fusion_network_output_loss: -0.2462 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00091: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 92/150
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4721 - deconvolution_network_output_loss: -0.2525 - deconvolution_fusion_network_output_loss: -0.2474 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00092: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 93/150
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4733 - deconvolution_network_output_loss: -0.2522 - deconvolution_fusion_network_output_loss: -0.2489 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00093: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 94/150
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4740 - deconvolution_network_output_loss: -0.2534 - deconvolution_fusion_network_output_loss: -0.2483 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00094: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 95/150
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4731 - deconvolution_network_output_loss: -0.2530 - deconvolution_fusion_network_output_loss: -0.2478 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00095: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 96/150
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4749 - deconvolution_network_output_loss: -0.2524 - deconvolution_fusion_network_output_loss: -0.2503 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00096: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 97/150
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4753 - deconvolution_network_output_loss: -0.2533 - deconvolution_fusion_network_output_loss: -0.2498 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00097: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 98/150
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4749 - deconvolution_network_output_loss: -0.2535 - deconvolution_fusion_network_output_loss: -0.2492 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00098: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 99/150
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4753 - deconvolution_network_output_loss: -0.2526 - deconvolution_fusion_network_output_loss: -0.2504 - deconvolution_network_output_acc: 0.9979 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00099: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 100/150
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4774 - deconvolution_network_output_loss: -0.2533 - deconvolution_fusion_network_output_loss: -0.2518 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9945
#
# Epoch 00100: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 101/150
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4762 - deconvolution_network_output_loss: -0.2536 - deconvolution_fusion_network_output_loss: -0.2502 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00101: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 102/150
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4763 - deconvolution_network_output_loss: -0.2531 - deconvolution_fusion_network_output_loss: -0.2508 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00102: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 103/150
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4783 - deconvolution_network_output_loss: -0.2532 - deconvolution_fusion_network_output_loss: -0.2528 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00103: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 104/150
#
# ...
#
# Epoch 00116: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 117/150
#
# Epoch 00117: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4834 - deconvolution_network_output_loss: -0.2547 - deconvolution_fusion_network_output_loss: -0.2561 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00117: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 118/150
#
# Epoch 00118: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4837 - deconvolution_network_output_loss: -0.2539 - deconvolution_fusion_network_output_loss: -0.2573 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00118: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 119/150
#
# Epoch 00119: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4850 - deconvolution_network_output_loss: -0.2543 - deconvolution_fusion_network_output_loss: -0.2582 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00119: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 120/150
#
# Epoch 00120: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 364ms/step - loss: -0.4850 - deconvolution_network_output_loss: -0.2548 - deconvolution_fusion_network_output_loss: -0.2577 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00120: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 121/150
#
# Epoch 00121: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4847 - deconvolution_network_output_loss: -0.2544 - deconvolution_fusion_network_output_loss: -0.2577 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00121: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 122/150
#
# Epoch 00122: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4866 - deconvolution_network_output_loss: -0.2543 - deconvolution_fusion_network_output_loss: -0.2598 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00122: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 123/150
#
# Epoch 00123: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4855 - deconvolution_network_output_loss: -0.2548 - deconvolution_fusion_network_output_loss: -0.2581 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00123: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 124/150
#
# Epoch 00124: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 358ms/step - loss: -0.4870 - deconvolution_network_output_loss: -0.2549 - deconvolution_fusion_network_output_loss: -0.2596 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00124: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 125/150
#
# Epoch 00125: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 356ms/step - loss: -0.4881 - deconvolution_network_output_loss: -0.2544 - deconvolution_fusion_network_output_loss: -0.2611 - deconvolution_network_output_acc: 0.9980 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00125: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 126/150
#
# Epoch 00126: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4865 - deconvolution_network_output_loss: -0.2549 - deconvolution_fusion_network_output_loss: -0.2591 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00126: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 127/150
#
# Epoch 00127: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.4879 - deconvolution_network_output_loss: -0.2550 - deconvolution_fusion_network_output_loss: -0.2603 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00127: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 128/150
#
# Epoch 00128: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.4890 - deconvolution_network_output_loss: -0.2545 - deconvolution_fusion_network_output_loss: -0.2618 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00128: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 129/150
#
# Epoch 00129: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.4889 - deconvolution_network_output_loss: -0.2552 - deconvolution_fusion_network_output_loss: -0.2611 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00129: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 130/150
#
# Epoch 00130: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 357ms/step - loss: -0.4892 - deconvolution_network_output_loss: -0.2552 - deconvolution_fusion_network_output_loss: -0.2614 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00130: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 131/150
#
# Epoch 00131: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 358ms/step - loss: -0.4896 - deconvolution_network_output_loss: -0.2546 - deconvolution_fusion_network_output_loss: -0.2623 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00131: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 132/150
#
# Epoch 00132: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 357ms/step - loss: -0.4904 - deconvolution_network_output_loss: -0.2552 - deconvolution_fusion_network_output_loss: -0.2625 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00132: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 133/150
#
# Epoch 00133: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.4900 - deconvolution_network_output_loss: -0.2555 - deconvolution_fusion_network_output_loss: -0.2619 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00133: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 134/150
#
# Epoch 00134: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4906 - deconvolution_network_output_loss: -0.2547 - deconvolution_fusion_network_output_loss: -0.2633 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00134: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 135/150
#
# Epoch 00135: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4923 - deconvolution_network_output_loss: -0.2551 - deconvolution_fusion_network_output_loss: -0.2645 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00135: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 136/150
#
# Epoch 00136: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4912 - deconvolution_network_output_loss: -0.2556 - deconvolution_fusion_network_output_loss: -0.2630 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00136: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 137/150
#
# Epoch 00137: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4919 - deconvolution_network_output_loss: -0.2549 - deconvolution_fusion_network_output_loss: -0.2643 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00137: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 138/150
#
# Epoch 00138: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4928 - deconvolution_network_output_loss: -0.2551 - deconvolution_fusion_network_output_loss: -0.2650 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00138: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 139/150
#
# Epoch 00139: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4927 - deconvolution_network_output_loss: -0.2555 - deconvolution_fusion_network_output_loss: -0.2645 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00139: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 140/150
#
# Epoch 00140: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 359ms/step - loss: -0.4926 - deconvolution_network_output_loss: -0.2554 - deconvolution_fusion_network_output_loss: -0.2646 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00140: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 141/150
#
# Epoch 00141: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4947 - deconvolution_network_output_loss: -0.2553 - deconvolution_fusion_network_output_loss: -0.2667 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00141: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 142/150
#
# Epoch 00142: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4931 - deconvolution_network_output_loss: -0.2555 - deconvolution_fusion_network_output_loss: -0.2648 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00142: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 143/150
#
# Epoch 00143: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 360ms/step - loss: -0.4950 - deconvolution_network_output_loss: -0.2558 - deconvolution_fusion_network_output_loss: -0.2665 - deconvolution_network_output_acc: 0.9982 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00143: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 144/150
#
# Epoch 00144: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4960 - deconvolution_network_output_loss: -0.2551 - deconvolution_fusion_network_output_loss: -0.2681 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00144: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 145/150
#
# Epoch 00145: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4944 - deconvolution_network_output_loss: -0.2558 - deconvolution_fusion_network_output_loss: -0.2659 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00145: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 146/150
#
# Epoch 00146: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4955 - deconvolution_network_output_loss: -0.2556 - deconvolution_fusion_network_output_loss: -0.2670 - deconvolution_network_output_acc: 0.9982 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00146: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 147/150
#
# Epoch 00147: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 361ms/step - loss: -0.4970 - deconvolution_network_output_loss: -0.2555 - deconvolution_fusion_network_output_loss: -0.2687 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00147: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 148/150
#
# Epoch 00148: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4967 - deconvolution_network_output_loss: -0.2560 - deconvolution_fusion_network_output_loss: -0.2679 - deconvolution_network_output_acc: 0.9982 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00148: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 149/150
#
# Epoch 00149: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 362ms/step - loss: -0.4961 - deconvolution_network_output_loss: -0.2560 - deconvolution_fusion_network_output_loss: -0.2673 - deconvolution_network_output_acc: 0.9982 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00149: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
# Epoch 150/150
#
# Epoch 00150: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - 36s 363ms/step - loss: -0.4982 - deconvolution_network_output_loss: -0.2555 - deconvolution_fusion_network_output_loss: -0.2699 - deconvolution_network_output_acc: 0.9981 - deconvolution_fusion_network_output_acc: 0.9946
#
# Epoch 00150: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model_sep_fusion_11119.h5
