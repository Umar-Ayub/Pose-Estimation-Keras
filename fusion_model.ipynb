# %%
import tensorflow as tf
# import tensorflow.contrib.eager as tfe
# tfe.enable_eager_execution()
import sys
sys.path.append(r'~/Pose Estimation Keras')
import cnn
from cnn import conv_base
from build_dataset import Dataset
import numpy as np
# from sklearn.preprocessing import normalize
from scipy import stats

from keras import layers
from keras import models
from keras import optimizers
import keras.backend as K
from keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler

from time import time
import cv2
import os
# Out:
# Using TensorFlow backend.
# /home/bhandawatlab_duke/.local/lib/python3.5/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
# Some Hyperparameters
total_frames = 5
frame_height = 224
frame_width = 224
frame_channels = 3
num_bodyparts = 6



def build_deconv_model():
    frame_tensor = conv_base.layers[0].get_input_at(0)
    resnet_output = cnn.convolution_network(frame_tensor)
    model_resnet = models.Model(inputs=[frame_tensor], outputs=[resnet_output])
    
    deconv_output = cnn.deconvolution_fusion_network(model_resnet.output)
    model_deconv = models.Model(inputs=[frame_tensor], outputs=[deconv_output])
    
    losses = {
        "deconvolution_fusion_network_output": "binary_crossentropy",
#         "spatial_fusion_output": "binary_crossentropy",
#         "optical_flow_output": "binary_crossentropy"
    }
    lossWeights = {"deconvolution_fusion_network_output": 1.0,}
#                    "spatial_fusion_output": 1.0,
#                    "optical_flow_output": 1.0}
    
#     opt = optimizers.SGD(lr = 0.0, momentum=0.9, nesterov=True)
    opt = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)
    model_deconv.compile( optimizer=opt, loss=losses, loss_weights=lossWeights, metrics = ["accuracy"])
    
    return model_deconv

model = build_deconv_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# resnet50 (Model)             (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 14, 14, 30)        552990
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 24)        6504
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 56, 56, 18)        3906
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 112, 112, 12)      1956
# _________________________________________________________________
# same (Conv2DTranspose)       (None, 224, 224, 6)       654
# _________________________________________________________________
# deconvolution_fusion_network (None, 224, 224, 1)       55
# =================================================================
# Total params: 24,153,777
# Trainable params: 24,100,657
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
import csv
def parse_csv(file):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        indices = []
        for line in csv_reader:
            indices.extend([int(f) for f in line if f!=''])
    return indices

indices = parse_csv('dataset_indices.csv')
print('Following Indices will be trained from dataset.h5: \n', indices)


import h5py
with h5py.File('../dataset.h5', 'r') as hf:
    # central_heatmap = hf['central_heatmap'][indices]
    frames = hf['frames'][indices]
    # heatmaps_individual = hf['heatmaps_individual'][indices]
    heatmaps_combined = hf['heatmaps_combined'][indices]


home_dir = os.getcwd()
heatmaps_combined = np.expand_dims(heatmaps_combined, axis=-1)

print('Shape of Training Data',heatmaps_combined.shape)
# Out:
# Following Indices will be trained from dataset.h5:
#  [0, 2, 3, 4, 6, 7, 8, 11, 15, 16, 17, 18, 19, 20, 23, 120, 126, 127, 178, 185, 199, 228, 244, 261, 267, 285, 306, 335, 367, 375, 389, 405, 410, 415, 420, 426, 430, 436, 440, 445, 452, 455, 460, 465, 470, 476, 480, 485, 490, 496, 500, 511, 520, 525, 530, 535, 542, 552, 555, 568, 570, 575, 581, 588, 595, 600, 605, 610, 615, 621, 625, 633, 636, 640, 645, 650, 655, 665, 670, 675, 680, 685, 690, 695, 700, 705, 710, 715, 718, 723, 725, 751, 755, 770, 783, 784, 804, 812, 816, 823, 829, 838, 841, 845, 850, 855, 863, 865, 891, 894, 904, 908, 915, 920, 929, 946, 953, 955, 959, 965, 970, 980, 987, 990, 995, 1030, 1035, 1041, 1045, 1160, 1164, 1170, 1174, 1220, 1225, 1230, 1235, 1240, 1245, 1250, 1255, 1267, 1275, 1280, 1285, 1290]
# Shape of Training Data (146, 5, 224, 224, 1)

# %%
def step_decay(epoch):
    try:
        if epoch < 30:
            lrate = 0.0001
        elif epoch < 70:
            lrate = 0.00005
        elif epoch < 200:
            lrate = 0.00001
        return lrate
    except:
        print('Error in setting learning rate')
        
lrate = LearningRateScheduler(step_decay, verbose=1)

checkpointer = ModelCheckpoint(filepath= os.path.join(home_dir, "pretrained_models/model011119_spatial.h5"),
                               verbose=1,
                               monitor='loss')

tensorboard = TensorBoard(log_dir=os.path.join(home_dir, "logs/{}".format(time())))



def normalize(x):
    x = np.array(x, dtype = np.float64)
    x -= np.mean(x, dtype = np.float64)
    x /= np.std(x, dtype = np.float64)
    return x


def generator(frames, heatmaps_combined):
    while(1):
        for j,l in zip(frames, heatmaps_combined):
#             print(l.shape[0])
            for channel in range(l.shape[0]):
                l[channel, :, :, :] = normalize(l[channel, :, :, :]) 
            # include batch dimension and repeat the matrix at axis 0 num_frames times to match the target dimensionality
            yield (j, {
#                 "optical_flow_output" : np.repeat(np.expand_dims(k, axis=0), 5, 0), 
                       "deconvolution_fusion_network_output": l})

# %%
model.fit_generator(generator(frames,
                                     heatmaps_combined),
                           steps_per_epoch=100, 
                           verbose = 2,
                           epochs = 150,
                           callbacks=[lrate, checkpointer, tensorboard])
# Out:
# Epoch 1/150
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0611 - acc: 0.9830
#
# Epoch 00001: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 2/150
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0486 - acc: 0.9847
#
# Epoch 00002: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 3/150
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0387 - acc: 0.9848
#
# Epoch 00003: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 4/150
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0332 - acc: 0.9842
#
# Epoch 00004: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 5/150
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0265 - acc: 0.9852
#
# Epoch 00005: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 6/150
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0201 - acc: 0.9857
#
# Epoch 00006: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 7/150
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0173 - acc: 0.9846
#
# Epoch 00007: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 8/150
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0114 - acc: 0.9854
#
# Epoch 00008: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 9/150
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0072 - acc: 0.9855
#
# Epoch 00009: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 10/150
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: 0.0021 - acc: 0.9866
#
# Epoch 00010: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 11/150
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -1.2231e-03 - acc: 0.9860
#
# Epoch 00011: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 12/150
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -5.5417e-03 - acc: 0.9868
#
# Epoch 00012: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 13/150
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -1.3800e-02 - acc: 0.9875
#
# Epoch 00013: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 14/150
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -1.4842e-02 - acc: 0.9874
#
# Epoch 00014: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 15/150
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -2.0403e-02 - acc: 0.9885
#
# Epoch 00015: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 16/150
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -2.6424e-02 - acc: 0.9886
#
# Epoch 00016: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 17/150
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -2.8748e-02 - acc: 0.9887
#
# Epoch 00017: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 18/150
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -3.1735e-02 - acc: 0.9892
#
# Epoch 00018: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 19/150
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0001.
#  - 35s - loss: -3.8135e-02 - acc: 0.9891
#
# Epoch 00019: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 20/150
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -4.0069e-02 - acc: 0.9897
#
# Epoch 00020: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 21/150
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -4.3584e-02 - acc: 0.9894
#
# Epoch 00021: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 22/150
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -4.7907e-02 - acc: 0.9894
#
# Epoch 00022: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 23/150
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -5.0298e-02 - acc: 0.9896
#
# Epoch 00023: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 24/150
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -5.5532e-02 - acc: 0.9901
#
# Epoch 00024: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 25/150
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -6.0184e-02 - acc: 0.9901
#
# Epoch 00025: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 26/150
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -6.0668e-02 - acc: 0.9899
#
# Epoch 00026: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 27/150
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -6.7966e-02 - acc: 0.9908
#
# Epoch 00027: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 28/150
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -7.1521e-02 - acc: 0.9905
#
# Epoch 00028: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 29/150
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -7.3935e-02 - acc: 0.9908
#
# Epoch 00029: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 30/150
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0001.
#  - 34s - loss: -7.9367e-02 - acc: 0.9912
#
# Epoch 00030: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 31/150
#
# Epoch 00031: LearningRateScheduler setting learning rate to 5e-05.
#  - 35s - loss: -8.1831e-02 - acc: 0.9913
#
# Epoch 00031: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 32/150
#
# Epoch 00032: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -8.7257e-02 - acc: 0.9914
#
# Epoch 00032: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 33/150
#
# Epoch 00033: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -9.0344e-02 - acc: 0.9926
#
# Epoch 00033: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 34/150
#
# Epoch 00034: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -9.1996e-02 - acc: 0.9927
#
# Epoch 00034: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 35/150
#
# Epoch 00035: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -9.8258e-02 - acc: 0.9931
#
# Epoch 00035: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 36/150
#
# Epoch 00036: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -9.9850e-02 - acc: 0.9934
#
# Epoch 00036: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 37/150
#
# Epoch 00037: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.0104e-01 - acc: 0.9936
#
# Epoch 00037: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 38/150
#
# Epoch 00038: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.0641e-01 - acc: 0.9938
#
# Epoch 00038: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 39/150
#
# Epoch 00039: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.0600e-01 - acc: 0.9939
#
# Epoch 00039: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 40/150
#
# Epoch 00040: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.0929e-01 - acc: 0.9939
#
# Epoch 00040: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 41/150
#
# Epoch 00041: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.1266e-01 - acc: 0.9940
#
# Epoch 00041: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 42/150
#
# Epoch 00042: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.1208e-01 - acc: 0.9941
#
# Epoch 00042: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 43/150
#
# Epoch 00043: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.1620e-01 - acc: 0.9940
#
# Epoch 00043: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 44/150
#
# Epoch 00044: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.1841e-01 - acc: 0.9942
#
# Epoch 00044: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 45/150
#
# Epoch 00045: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.1816e-01 - acc: 0.9941
#
# Epoch 00045: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 46/150
#
# Epoch 00046: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2006e-01 - acc: 0.9939
#
# Epoch 00046: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 47/150
#
# Epoch 00047: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2289e-01 - acc: 0.9939
#
# Epoch 00047: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 48/150
#
# Epoch 00048: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2300e-01 - acc: 0.9936
#
# Epoch 00048: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 49/150
#
# Epoch 00049: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2455e-01 - acc: 0.9937
#
# Epoch 00049: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 50/150
#
# Epoch 00050: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2553e-01 - acc: 0.9938
#
# Epoch 00050: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 51/150
#
# Epoch 00051: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2835e-01 - acc: 0.9932
#
# Epoch 00051: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 52/150
#
# Epoch 00052: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2711e-01 - acc: 0.9931
#
# Epoch 00052: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 53/150
#
# Epoch 00053: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.2785e-01 - acc: 0.9932
#
# Epoch 00053: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 54/150
#
# Epoch 00054: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.3260e-01 - acc: 0.9931
#
# Epoch 00054: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 55/150
#
# Epoch 00055: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.3296e-01 - acc: 0.9933
#
# Epoch 00055: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 56/150
#
# Epoch 00056: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.3531e-01 - acc: 0.9935
#
# Epoch 00056: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 57/150
#
# Epoch 00057: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.4023e-01 - acc: 0.9935
#
# Epoch 00057: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 58/150
#
# Epoch 00058: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.3800e-01 - acc: 0.9935
#
# Epoch 00058: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 59/150
#
# Epoch 00059: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.4240e-01 - acc: 0.9937
#
# Epoch 00059: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 60/150
#
# Epoch 00060: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.4556e-01 - acc: 0.9937
#
# Epoch 00060: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 61/150
#
# Epoch 00061: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.4268e-01 - acc: 0.9933
#
# Epoch 00061: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 62/150
#
# Epoch 00062: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.4864e-01 - acc: 0.9937
#
# Epoch 00062: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 63/150
#
# Epoch 00063: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.4814e-01 - acc: 0.9933
#
# Epoch 00063: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 64/150
#
# Epoch 00064: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.4913e-01 - acc: 0.9935
#
# Epoch 00064: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 65/150
#
# Epoch 00065: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.5309e-01 - acc: 0.9938
#
# Epoch 00065: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 66/150
#
# Epoch 00066: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.5440e-01 - acc: 0.9937
#
# Epoch 00066: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 67/150
#
# Epoch 00067: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.5726e-01 - acc: 0.9936
#
# Epoch 00067: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 68/150
#
# Epoch 00068: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.5932e-01 - acc: 0.9940
#
# Epoch 00068: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 69/150
#
# Epoch 00069: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.5766e-01 - acc: 0.9936
#
# Epoch 00069: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 70/150
#
# Epoch 00070: LearningRateScheduler setting learning rate to 5e-05.
#  - 34s - loss: -1.6447e-01 - acc: 0.9938
#
# Epoch 00070: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 71/150
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6296e-01 - acc: 0.9938
#
# Epoch 00071: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 72/150
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6243e-01 - acc: 0.9939
#
# Epoch 00072: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 73/150
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6796e-01 - acc: 0.9942
#
# Epoch 00073: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 74/150
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6628e-01 - acc: 0.9942
#
# Epoch 00074: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 75/150
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6779e-01 - acc: 0.9944
#
# Epoch 00075: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 76/150
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6972e-01 - acc: 0.9944
#
# Epoch 00076: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 77/150
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6811e-01 - acc: 0.9944
#
# Epoch 00077: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 78/150
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6988e-01 - acc: 0.9945
#
# Epoch 00078: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 79/150
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7162e-01 - acc: 0.9945
#
# Epoch 00079: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 80/150
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.6888e-01 - acc: 0.9945
#
# Epoch 00080: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 81/150
#
# Epoch 00081: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7196e-01 - acc: 0.9945
#
# Epoch 00081: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 82/150
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7244e-01 - acc: 0.9946
#
# Epoch 00082: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 83/150
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7082e-01 - acc: 0.9945
#
# Epoch 00083: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 84/150
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7212e-01 - acc: 0.9945
#
# Epoch 00084: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 85/150
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7151e-01 - acc: 0.9947
#
# Epoch 00085: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 86/150
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7560e-01 - acc: 0.9945
#
# Epoch 00086: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 87/150
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7353e-01 - acc: 0.9946
#
# Epoch 00087: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 88/150
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7257e-01 - acc: 0.9947
#
# Epoch 00088: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 89/150
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7672e-01 - acc: 0.9946
#
# Epoch 00089: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 90/150
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7523e-01 - acc: 0.9946
#
# Epoch 00090: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 91/150
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7377e-01 - acc: 0.9947
#
# Epoch 00091: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 92/150
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7769e-01 - acc: 0.9946
#
# Epoch 00092: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 93/150
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7508e-01 - acc: 0.9946
#
# Epoch 00093: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 94/150
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7678e-01 - acc: 0.9947
#
# Epoch 00094: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 95/150
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
#  - 35s - loss: -1.7831e-01 - acc: 0.9946
#
# Epoch 00095: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 96/150
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
#  - 35s - loss: -1.7681e-01 - acc: 0.9946
#
# Epoch 00096: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 97/150
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
#  - 35s - loss: -1.7861e-01 - acc: 0.9946
#
# Epoch 00097: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 98/150
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.7964e-01 - acc: 0.9947
#
# Epoch 00098: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 99/150
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
#  - 35s - loss: -1.7791e-01 - acc: 0.9946
#
# Epoch 00099: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 100/150
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
#  - 35s - loss: -1.8044e-01 - acc: 0.9946
#
# Epoch 00100: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 101/150
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
#  - 35s - loss: -1.8054e-01 - acc: 0.9947
#
# Epoch 00101: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 102/150
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8050e-01 - acc: 0.9946
#
# Epoch 00102: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 103/150
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8168e-01 - acc: 0.9946
#
# Epoch 00103: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 104/150
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8092e-01 - acc: 0.9947
#
# Epoch 00104: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 105/150
#
# Epoch 00105: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8334e-01 - acc: 0.9946
#
# Epoch 00105: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 106/150
#
# Epoch 00106: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8310e-01 - acc: 0.9947
#
# Epoch 00106: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 107/150
#
# Epoch 00107: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8204e-01 - acc: 0.9947
#
# Epoch 00107: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 108/150
#
# Epoch 00108: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8414e-01 - acc: 0.9947
#
# Epoch 00108: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 109/150
#
# Epoch 00109: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8480e-01 - acc: 0.9946
#
# Epoch 00109: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 110/150
#
# Epoch 00110: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8322e-01 - acc: 0.9947
#
# Epoch 00110: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 111/150
#
# Epoch 00111: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8520e-01 - acc: 0.9947
#
# Epoch 00111: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 112/150
#
# Epoch 00112: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8437e-01 - acc: 0.9947
#
# Epoch 00112: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 113/150
#
# Epoch 00113: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8593e-01 - acc: 0.9947
#
# Epoch 00113: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 114/150
#
# Epoch 00114: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8584e-01 - acc: 0.9947
#
# Epoch 00114: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 115/150
#
# Epoch 00115: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8507e-01 - acc: 0.9947
#
# Epoch 00115: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 116/150
#
# Epoch 00116: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8813e-01 - acc: 0.9947
#
# Epoch 00116: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 117/150
#
# Epoch 00117: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8635e-01 - acc: 0.9947
#
# Epoch 00117: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 118/150
#
# Epoch 00118: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8680e-01 - acc: 0.9947
#
# Epoch 00118: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 119/150
#
# Epoch 00119: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8798e-01 - acc: 0.9947
#
# Epoch 00119: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 120/150
#
# Epoch 00120: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8882e-01 - acc: 0.9947
#
# Epoch 00120: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 121/150
#
# Epoch 00121: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8797e-01 - acc: 0.9947
#
# Epoch 00121: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 122/150
#
# Epoch 00122: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8923e-01 - acc: 0.9947
#
# Epoch 00122: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 123/150
#
# Epoch 00123: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8831e-01 - acc: 0.9948
#
# Epoch 00123: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 124/150
#
# Epoch 00124: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9058e-01 - acc: 0.9947
#
# Epoch 00124: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 125/150
#
# Epoch 00125: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9063e-01 - acc: 0.9947
#
# Epoch 00125: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 126/150
#
# Epoch 00126: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.8932e-01 - acc: 0.9948
#
# Epoch 00126: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 127/150
#
# Epoch 00127: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9140e-01 - acc: 0.9947
#
# Epoch 00127: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 128/150
#
# Epoch 00128: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9142e-01 - acc: 0.9947
#
# Epoch 00128: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 129/150
#
# Epoch 00129: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9132e-01 - acc: 0.9948
#
# Epoch 00129: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 130/150
#
# Epoch 00130: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9251e-01 - acc: 0.9947
#
# Epoch 00130: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 131/150
#
# Epoch 00131: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9129e-01 - acc: 0.9947
#
# Epoch 00131: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 132/150
#
# Epoch 00132: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9345e-01 - acc: 0.9947
#
# Epoch 00132: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 133/150
#
# Epoch 00133: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9318e-01 - acc: 0.9948
#
# Epoch 00133: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 134/150
#
# Epoch 00134: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9226e-01 - acc: 0.9947
#
# Epoch 00134: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 135/150
#
# Epoch 00135: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9538e-01 - acc: 0.9947
#
# Epoch 00135: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 136/150
#
# Epoch 00136: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9356e-01 - acc: 0.9948
#
# Epoch 00136: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 137/150
#
# Epoch 00137: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9410e-01 - acc: 0.9947
#
# Epoch 00137: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 138/150
#
# Epoch 00138: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9527e-01 - acc: 0.9947
#
# Epoch 00138: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 139/150
#
# Epoch 00139: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9601e-01 - acc: 0.9948
#
# Epoch 00139: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 140/150
#
# Epoch 00140: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9515e-01 - acc: 0.9947
#
# Epoch 00140: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 141/150
#
# Epoch 00141: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9658e-01 - acc: 0.9948
#
# Epoch 00141: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 142/150
#
# Epoch 00142: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9537e-01 - acc: 0.9948
#
# Epoch 00142: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 143/150
#
# Epoch 00143: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9785e-01 - acc: 0.9948
#
# Epoch 00143: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 144/150
#
# Epoch 00144: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9792e-01 - acc: 0.9947
#
# Epoch 00144: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 145/150
#
# Epoch 00145: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9653e-01 - acc: 0.9948
#
# Epoch 00145: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 146/150
#
# Epoch 00146: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9851e-01 - acc: 0.9948
#
# Epoch 00146: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 147/150
#
# Epoch 00147: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9790e-01 - acc: 0.9947
#
# Epoch 00147: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 148/150
#
# Epoch 00148: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9929e-01 - acc: 0.9948
#
# Epoch 00148: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 149/150
#
# Epoch 00149: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9894e-01 - acc: 0.9948
#
# Epoch 00149: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
# Epoch 150/150
#
# Epoch 00150: LearningRateScheduler setting learning rate to 1e-05.
#  - 34s - loss: -1.9913e-01 - acc: 0.9948
#
# Epoch 00150: saving model to /home/bhandawatlab_duke/Pose-Estimation-Keras/pretrained_models/model011119_spatial.h5
